# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaenariya/IPcolab/blob/main/2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/gdrive')
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/내 드라이브/디지털 영상처리/1주차/Images/girl.jpg', cv2.IMREAD_COLOR)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-230595649.py in <cell line: 0>()
#       1 img = cv2.imread('/content/gdrive/내 드라이브/디지털 영상처리/1주차/Images/girl.jpg', cv2.IMREAD_COLOR)
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img_path = '/content/gdrive/내 드라이브/디지털 영상처리/1주차/Images/girl.jpg'

img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1017505248.py in <cell line: 0>()
#       2
#       3 img = cv2.imread(img_path)
# ----> 4 cv2_imshow(img)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
RGB_img = cv2.cvtColor(img.cv2.COLOR_GGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1820425157.py in <cell line: 0>()
# ----> 1 RGB_img = cv2.cvtColor(img.cv2.COLOR_GGR2RGB)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cv2'

# %%
plt.imshow(img)

# %%
img_path = '/content/gdrive/My Drive/test/sky.jpg'

img = cv2.imread(img_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=975x650>
