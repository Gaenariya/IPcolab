# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaenariya/IPcolab/blob/main/5-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/lena256.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg1)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
def saturation(value):
  if(value > 255):
    value= 255
  elif(value < 0):
    value = 0
  return value

# %%
kernel3 = np.ones((3,3), np.float32)/9
kernel5 = np.ones((5,5), np.float32)/25
kernel7 = np.ones((7,7), np.float32)/49

# %%
output = cv2.filter2D(gimg1, -1, kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
output = cv2.filter2D(gimg1, -1, kernel5)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
output = cv2.filter2D(gimg1, -1, kernel7)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gOut = np.zeros((gimg1.shape[0],gimg1.shape[1]), dtype=np.ubyte)

# %%
for h in range(1, gimg1.shape[0]-1):
  for w in range(1, gimg1.shape[1]-1):
    sum = 0
    for i in range(-1, 2):
      for j in range(-1, 2):
        sum += gimg1[h+i, w+j] * kernel3[i+1, j+1]
    sum = saturation(sum)
    gOut[h, w] = sum

cv2_imshow(gOut)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
output = cv2.filter2D(output, -1, kernel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] =  8/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
output = cv2.filter2D(gimg1, -1, kernel3)
#cv2_imshow(output)
output = output * 5
plt.imshow(output, cmap='gray')

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/fcespnoise.bmp')
#img = cv2.imread('/content/gdrive/My Drive/Images/LenaG2.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3404758039.py in <cell line: 0>()
#       1 img = cv2.imread('/content/gdrive/My Drive/Images/fcespnoise.bmp')
#       2 #img = cv2.imread('/content/gdrive/My Drive/Images/LenaG2.jpg')
# ----> 3 print(img.shape)
#       4 gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#       5 #plt.imshow(gimg1, cmap='gray')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
outimg = cv2.blur(gimg1, (3,3))
#cv2_imshow(outimg)
plt.imshow(outimg, cmap='gray')

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/fcespnoise.bmp')
#img = cv2.imread('/content/gdrive/My Drivel/Images/LenaG2.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg1)

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/fcespnoise.bmp')
#img = cv2.imread('/content/gdrive/My Drive/Images/LenaG2.jpg')
print(img.shape)
gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3404758039.py in <cell line: 0>()
#       1 img = cv2.imread('/content/gdrive/My Drive/Images/fcespnoise.bmp')
#       2 #img = cv2.imread('/content/gdrive/My Drive/Images/LenaG2.jpg')
# ----> 3 print(img.shape)
#       4 gimg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#       5 #plt.imshow(gimg1, cmap='gray')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
outimg = cv2.medianBlur(gimg1, 3)
#cv2_imshow(outimg)
plt.imshow(outimg, cmap='gray')
