# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaenariya/IPcolab/blob/main/7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/gdrive')
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Mounted at /content/gdrive

# %%
def saturation(val):
  if val > 255:
    return 255
  elif val < 0:
    return 0
  else:
    return val

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/lena.jpg')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#rint(gImg.shape)
#plt.axis('off')
cv2_imshow(gImg)
# Out:
# (512, 512, 3)
# <PIL.Image.Image image mode=L size=512x512>

# %%
hist = cv2.calcHist([gImg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/rice.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gImg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gImg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/cell.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gImg)
# Out:
# (360, 360, 3)
# <PIL.Image.Image image mode=L size=360x360>

# %%
hist = cv2.calcHist([gImg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/milkdrop.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gImg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gImg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
Threshold = 180
gBin = np.zeros((gImg.shape[0], gImg.shape[1]), dtype = np.ubyte)

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if gImg[h, w] > Threshold:
      gBin[h, w] = 255
    else:
      gBin[h, w] = 0

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/rice.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gImg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
Threshold = 180
gBin = np.zeros((gImg.shape[0], gImg.shape[1]), dtype = np.ubyte)

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if gImg[h, w] > Threshold:
      gBin[h, w] = 255
    else:
      gBin[h, w] = 0

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/medicine.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gImg)
# Out:
# (360, 360, 3)
# <PIL.Image.Image image mode=L size=360x360>

# %%
Threshold = 140
gBin = np.zeros((gImg.shape[0], gImg.shape[1]), dtype = np.ubyte)

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if gImg[h, w] > Threshold:
      gBin[h, w] = 255
    else:
      gBin[h, w] = 0

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=360x360>

# %%
t1 = 128
t2 = 0
t0 = 1

def threshold_update(Img, bImg):
  sum1 = 0
  count1 = 1
  sum2 = 0
  count2 = 1

  for h in range(Img.shape[0]):
    for w in range(Img.shape[1]):
      if bImg[h, w] == 0:
        sum1 += Img[h, w]
        count1 += 1
      else:
        sum2 += Img[h, w]
        count2 += 1

  avg1 = sum1/count1
  avg2 = sum2/count2
  T = (avg1 + avg2)/2
  return T

# %%
while True:
  t2 = threshold_update(gImg, gBin)

  if(np.abs(T1-T2) < 0):
    break
  else:
    t1 = t2
    for h in range(gImg.shape[0]):
      for w in range(gImg.shape[2]):
        if gImg[h, w] > t1:
          gBin[h, w] = 0
        else:
          gBing[h, w] = 255

  print(12)
  cv2_imshow(gBin)
# Out:
# /tmp/ipython-input-2792114065.py:17: RuntimeWarning: overflow encountered in scalar add
#   sum2 += Img[h, w]
# Optimal Threshold: 0.002189170225711125
# <PIL.Image.Image image mode=L size=360x360>
